# %%
# %load_ext autoreload

# %autoreload 2

# %%
from dotenv import load_dotenv
import os

load_dotenv()
fb_email = os.environ["FB_EMAIL"]
fb_password = os.environ["FB_PASSWORD"]

# %%
from news_breaker.facebook import Facebook
facebook = Facebook(fb_email, fb_password, "ETtoday", True)

await facebook.run()
# Out:
# [2023-06-22 22:52:59,802] [INFO] [Facebook] Logging in...
# [2023-06-22 22:53:05,925] [INFO] [Facebook] Login complete
# [2023-06-22 22:53:09,887] [INFO] [Facebook] Got news: https://www.ettoday.net/news/20230622/2525647.htm......
# [2023-06-22 22:53:09,888] [INFO] [ArticleSummarizer] [START] Summarize https://www.ettoday.net/news/20230622/2525647.htm......
# [2023-06-22 22:53:10,255] [INFO] [ArticleSummarizer] Navigating to https://www.ettoday.net/news/20230622/2525647.htm.........
# [2023-06-22 22:53:17,192] [INFO] [ArticleSummarizer] Getting article text...
# ...
